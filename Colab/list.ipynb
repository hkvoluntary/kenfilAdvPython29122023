# %%
#Lists are used to store multiple items in a single variable.
#List items are ordered, changeable, and allow duplicate values.

thislist = ["apple","banana","cherry", "orange", "kiwi", "apple", "melon","mango"]
print(thislist)
thislist.remove("apple")
print(thislist)
thislist.remove("apple")
print(thislist)

list1 = ["apple"]
print(type(list1))

# %%
thislist = ["apple","banana","cherry", "orange", "kiwi", "apple", "melon","mango"]
print(thislist[2:len(thislist)]) #index from 2 to size of list - 1. This case is 8-1
print(thislist[2:6])
print(thislist[-1])
print(thislist[-4:-1])
thislist[1] = "pear"
print(thislist)

# %%
for x in thislist:
  print(x)

# %%
if "apple" in thislist:
  print("Yes, 'apple' is in the fruits list")

# %%
thislist = ["apple", "banana", "cherry"]
thislist.append("orange")
print(thislist)

# %%
thislist = ["apple", "banana", "cherry"]
thislist.insert(1, "orange")
print(thislist)

# %%
thislist = ["apple", "banana", "cherry"]
thislist.remove("banana")
print(thislist)

# %%
thislist = ["apple", "banana", "cherry"]
thislist.pop()
print(thislist)

# %%
thislist = ["apple", "banana", "cherry"]
del thislist[0]
print(thislist)

# %%
thislist = ["apple", "banana", "cherry"]
del thislist
print(thislist)

# %%
thislist = ["apple", "banana", "cherry"]
thislist.clear()
print(thislist)

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist.copy()
print("thislist:", thislist, "mylist:", mylist)

# %%
thislist = ["apple", "banana", "cherry"]
mylist = list(thislist)
print("thislist:", thislist, "mylist:", mylist)

# %%
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]
list3 = list1 + list2
print(list3)

# %%
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]
for x in list2:
  list1.append(x)
print(list1)

# %%
list1 = ["a", "b" , "c"]
ist2 = [1, 2, 3]
list1.extend(list2)
print(list1)
